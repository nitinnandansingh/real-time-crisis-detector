# %%
import pandas as pd
import spacy
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import fasttext

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Load Sentiment140 dataset

# %%
senti_df = pd.read_csv('../data/raw/sentiment140.csv', names=['target', 'id', 'date', 'flag', 'user', 'text'])
print(senti_df.shape)
senti_df.head(5)
# Out:
# (1600000, 6)
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
senti_df.target.value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %% [markdown]
# There are only 0 and 4 as values of target. `0: negative` , `4: positive`

# %%
senti_df.flag.value_counts()
# Out:
# flag
# NO_QUERY    1600000
# Name: count, dtype: int64

# %%
senti_df = senti_df[['target', 'text']]
print(senti_df.shape)
senti_df.head(5)
# Out:
# (1600000, 2)
#    target                                               text
# 0       0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1       0  is upset that he can't update his Facebook by ...
# 2       0  @Kenichan I dived many times for the ball. Man...
# 3       0    my whole body feels itchy and like its on fire
# 4       0  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# ## Load eyewitness dataset

# %%
df1 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_authors/earthquakes_eyewitness_annotations_2000.tsv', sep='\t')
print(df1.shape)
df1.head(5)
# Out:
# (2000, 15)
#                                                 text           label  \
# 0  #earthquake Magnitude 2.1 occurred 159km NE of...  non-eyewitness
# 1  Retweeted Earthquakes Tsunamis (@NewEarthquake...  non-eyewitness
# 2  I always know I need to go shopping when I've ...      don't know
# 3  Update: M2.0 #earthquake (#sismo) strikes 1 km...  non-eyewitness
# 4                                                 ã€  non-eyewitness
#
#                                               source  \
# 0  <a href="http://www.didyoufeel.it/" rel="nofol...
# 1  <a href="http://www.facebook.com/twitter" rel=...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://www.emsc-csem.org/" rel="nofol...
# 4      <a href="http://twdesk.com/" rel="nofollow">ã
#
#                        created_at lang  listed_count verified  \
# 0  Tue Aug 01 08:12:42 +0000 2017   en           7.0        f
# 1  Tue Aug 01 08:13:08 +0000 2017   en         287.0        f
# 2  Tue Aug 01 08:13:15 +0000 2017   en           0.0        f
# 3  Tue Aug 01 08:13:48 +0000 2017   en         392.0        f
# 4  Tue Aug 01 08:14:58 +0000 2017   en          54.0        f
#
#                                        location  statuses_count  \
# 0                                        Italia         92091.0
# 1                                      Malaysia        100720.0
# 2  Hollywood, California, USA..... planet earth          2206.0
# 3                   BruyÃ¨res-Le-Chatel, France         98956.0
# 4                                 With everyone        265090.0
#
#    followers_count  favourites_count        time_zone user_lang  \
# 0           1248.0               1.0  Central America        en
# 1           1680.0           13260.0     Kuala Lumpur        en
# 2             89.0             959.0              NaN        en
# 3           8970.0               1.0         Belgrade        fr
# 4           4165.0              29.0          Irkutsk        ja
#
#    friends_count      screen_name
# 0         1756.0  did_you_feel_it
# 1         2486.0         LimAiYim
# 2           85.0   3DennisCarlins
# 3            3.0             EMSC
# 4         3800.0     from___japan

# %%
df1.isnull().sum()
# Out:
# text                  0
# label                 0
# source                8
# created_at            8
# lang                  8
# listed_count          8
# verified              8
# location            571
# statuses_count        8
# followers_count       8
# favourites_count      8
# time_zone           671
# user_lang             8
# friends_count         8
# screen_name           8
# dtype: int64

# %%
df1 = df1[['label', 'text']]  
print(df1.shape)
df1.head(3)
# Out:
# (2000, 2)
#             label                                               text
# 0  non-eyewitness  #earthquake Magnitude 2.1 occurred 159km NE of...
# 1  non-eyewitness  Retweeted Earthquakes Tsunamis (@NewEarthquake...
# 2      don't know  I always know I need to go shopping when I've ...

# %%
df2 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_authors/floods_eyewitness_annotations_2000.tsv', sep='\t')
print(df2.shape)
df2.head(5)
# Out:
# (2000, 15)
#                                                 text              lable  \
# 0  There are still like 8473 bugs. This is the wo...  direct-eyewitness
# 1  I am now at the right bank to cross the flood....  direct-eyewitness
# 2  859 PM MDT: Very heavy rain near Red Bluff Lak...  direct-eyewitness
# 3  The thunder and heavy rainfall woke me up seve...  direct-eyewitness
# 4  Got a little bit of rain today #onstorm #orang...  direct-eyewitness
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://www.hootsuite.com" rel="nofoll...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                        created_at lang  listed_count verified  \
# 0  Tue Aug 01 00:07:43 +0000 2017   en            71        f
# 1  Tue Aug 01 00:36:25 +0000 2017   en             0        f
# 2  Tue Aug 01 02:59:21 +0000 2017   en           290        t
# 3  Wed Aug 02 00:08:05 +0000 2017   en             5        f
# 4  Wed Aug 02 00:10:45 +0000 2017   en             1        f
#
#                          location  statuses_count  followers_count  \
# 0                             NaN          190274             2190
# 1                       Ahmedabad              14               21
# 2                  Midland, Texas           14756             6251
# 3  Pasig City, Manila Philippines            7268              375
# 4             Orangeville, Canada             899              195
#
#    favourites_count                   time_zone user_lang  friends_count  \
# 0             15301  Eastern Time (US & Canada)        en           1502
# 1                 3                      Mumbai        en              5
# 2               695  Central Time (US & Canada)        en            135
# 3              1259                         NaN        en            340
# 4               116  Central Time (US & Canada)        en            762
#
#       screen_name
# 0    PupsAndPucks
# 1     rahulmtomar
# 2      NWSMidland
# 3  iamkringmanalo
# 4      _leafsgal_

# %%
df2.rename(columns={'lable': 'label'}, inplace=True)

# %%
df2 = df2[['label', 'text']]  
print(df2.shape)
df2.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct-eyewitness  There are still like 8473 bugs. This is the wo...
# 1  direct-eyewitness  I am now at the right bank to cross the flood....
# 2  direct-eyewitness  859 PM MDT: Very heavy rain near Red Bluff Lak...

# %%
df3 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_authors/hurricanes_eyewitness_annotations_2004.tsv', sep='\t')
print(df3.shape)
df3.head(5)
# Out:
# (2000, 15)
#                                                 text              Lable  \
# 0  I'm at the outer edge of the projected hurrica...  direct-eyewitness
# 1  school was cancelled today due to the heavy ra...  direct-eyewitness
# 2  So much shit is happening to us in Texas,, hur...  direct-eyewitness
# 3  sooo last year it decides to flood right befor...  direct-eyewitness
# 4  So we're having an earthquake AND a hurricane ...  direct-eyewitness
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                        created_at lang  listed_count verified        location  \
# 0  Fri Aug 25 02:00:19 +0000 2017   en             1        f              TX
# 1  Fri Aug 25 12:38:54 +0000 2017   en             0        f  houston, texas
# 2  Fri Aug 25 13:35:32 +0000 2017   en             2        f     Houston, TX
# 3  Fri Aug 25 14:33:30 +0000 2017   en             1        f             NaN
# 4  Fri Aug 25 14:58:46 +0000 2017   en             1        f      Dallas, TX
#
#    statuses_count  followers_count  favourites_count  \
# 0           35118               41               804
# 1             122              198                38
# 2           41575              254              9155
# 3             927              236               247
# 4            6096              225              4682
#
#                     time_zone user_lang  friends_count     screen_name
# 0  Central Time (US & Canada)        en             82      gothxingmi
# 1                         NaN        en            254  hurtingjohnson
# 2                         NaN        en            459     kimhandsoap
# 3                         NaN        en            266     _hguilbeau_
# 4                         NaN        en            123     jimenez_410

# %%
df3.rename(columns={'Lable': 'label'}, inplace=True)

# %%
df3.isnull().sum()
# Out:
# text                  1
# label                 0
# source                0
# created_at            0
# lang                  0
# listed_count          0
# verified              0
# location            497
# statuses_count        0
# followers_count       0
# favourites_count      0
# time_zone           777
# user_lang             0
# friends_count         0
# screen_name           0
# dtype: int64

# %%
df3 = df3[['label', 'text']]  
print(df3.shape)
df3.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct-eyewitness  I'm at the outer edge of the projected hurrica...
# 1  direct-eyewitness  school was cancelled today due to the heavy ra...
# 2  direct-eyewitness  So much shit is happening to us in Texas,, hur...

# %%
df4 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_crowdflower_paid_workers/earthquakes_eyewitness_crowdflower_2000.tsv', sep='\t')
print(df4.shape)
df4.head(3)
# Out:
# (2000, 13)
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  1846692712    False   finalized                   3  08/03/2018 20:23
# 1  1846692769    False   finalized                   3  08/03/2018 20:46
# 2  1846692882    False   finalized                   3  08/03/2018 21:36
#
#    please_choose_a_category:confidence                      created_at  \
# 0                               0.6664  Mon May 14 22:49:14 +0000 2018
# 1                               1.0000  Tue May 15 02:19:00 +0000 2018
# 2                               1.0000  Tue May 15 02:19:12 +0000 2018
#
#                  id_str  rownames please_choose_a_category  \
# 0  ,996160536487358464,     79959        direct_eyewitness
# 1  ,996213327398289408,     99307        direct_eyewitness
# 2  ,996213376370950144,     99629        direct_eyewitness
#
#                                                 text  Unnamed: 11  Unnamed: 12
# 0   TheReformedCrow Nah, I'm gonna go with earthq...          NaN          NaN
# 1                  I think we just had an earthquake          NaN          NaN
# 2              Uhh who else felt that earthquake tho          NaN          NaN

# %%
df4.please_choose_a_category.value_counts()
# Out:
# please_choose_a_category
# direct_eyewitness    1600
# dont_know             200
# noneyewitness         200
# Name: count, dtype: int64

# %%
df4 = df4[['please_choose_a_category','text']]
df4.rename(columns={'please_choose_a_category': 'label'}, inplace=True)
print(df4.shape)
df4.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct_eyewitness   TheReformedCrow Nah, I'm gonna go with earthq...
# 1  direct_eyewitness                  I think we just had an earthquake
# 2  direct_eyewitness              Uhh who else felt that earthquake tho

# %%
df5 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_crowdflower_paid_workers/floods_eyewitness_crowdflower_2000.tsv', sep='\t')
print(df5.shape)
df5.head(3)
# Out:
# (2000, 11)
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  1847304628    False   finalized                   3  08/05/2018 22:21
# 1  1847305169    False   finalized                   3   08/05/2018 2:21
# 2  1847306041    False   finalized                   3   08/06/2018 9:08
#
#    please_choose_a_category:confidence                      created_at  \
# 0                               1.0000  Thu Jul 05 20:50:28 +0000 2018
# 1                               0.6466  Thu Jul 19 17:10:31 +0000 2018
# 2                               0.6510  Mon Jul 04 16:41:38 +0000 2016
#
#                   id_str  rownames please_choose_a_category  \
# 0  ,1014974815764037632,     94671        direct_eyewitness
# 1  ,1019992896550985728,     27005        direct_eyewitness
# 2   ,750006667492855808,     26899        direct_eyewitness
#
#                                                 text
# 0  My state, everybody. Drought, fire, flood, hai...
# 1  Somebody please shoot me!   I have been breaki...
# 2  It's fine. It's all fucking fine. I'm just a d...

# %%
df5.please_choose_a_category.value_counts()
# Out:
# please_choose_a_category
# dont_know            822
# direct_eyewitness    627
# noneyewitness        551
# Name: count, dtype: int64

# %%
df5 = df5[['please_choose_a_category','text']]
df5.rename(columns={'please_choose_a_category': 'label'}, inplace=True)
print(df5.shape)
df5.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct_eyewitness  My state, everybody. Drought, fire, flood, hai...
# 1  direct_eyewitness  Somebody please shoot me!   I have been breaki...
# 2  direct_eyewitness  It's fine. It's all fucking fine. I'm just a d...

# %%
df6 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_crowdflower_paid_workers/forestfires_eyewitness_crowdflower_2000.tsv', sep='\t')
print(df6.shape)
df6.head(3)
# Out:
# (2000, 13)
#      _unit_id  _golden _unit_state  _trusted_judgments   _last_judgment_at  \
# 0  1830763346    False   finalized                   3  7/26/2018 12:30:49
# 1  1830764158    False   finalized                   3  7/26/2018 11:16:12
# 2  1830764254    False   finalized                   3  7/26/2018 11:24:49
#
#    please_choose_a_category_:confidence                      created_at  \
# 0                                1.0000  Sat May 07 07:17:21 +0000 2016
# 1                                0.6493  Tue Oct 10 18:41:33 +0000 2017
# 2                                0.6678  Tue Oct 10 19:55:29 +0000 2017
#
#                  id_str  rownames please_choose_a_category_  \
# 0  ,728846163798020096,     50034         direct_eyewitness
# 1  ,917822427903623168,      3296         direct_eyewitness
# 2  ,917841031520849920,     12921         direct_eyewitness
#
#                                                 text  Unnamed: 11  Unnamed: 12
# 0  Damn this Canadian Wildfire got the whole city...          NaN          NaN
# 1  Devastating to see such widespread destruction...          NaN          NaN
# 2  Sonoma county is covered in heavy thick black ...          NaN          NaN

# %%
df6.please_choose_a_category_.value_counts()
# Out:
# please_choose_a_category_
# noneyewitness        1379
# dont_know             432
# direct_eyewitness     189
# Name: count, dtype: int64

# %%
df6 = df6[['please_choose_a_category_','text']]
df6.rename(columns={'please_choose_a_category_': 'label'}, inplace=True)
print(df6.shape)
df6.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct_eyewitness  Damn this Canadian Wildfire got the whole city...
# 1  direct_eyewitness  Devastating to see such widespread destruction...
# 2  direct_eyewitness  Sonoma county is covered in heavy thick black ...

# %%
df7 = pd.read_csv('../data/raw/eyewitness_tweets_annotations_14k_public/labeled_by_crowdflower_paid_workers/hurricanes_eyewitness_crowdflower_2000.tsv', sep='\t')
print(df7.shape)
df7.head(3)
# Out:
# (2000, 12)
#      _unit_id  _golden _unit_state  _trusted_judgments   _last_judgment_at  \
# 0  1834490755    False   finalized                   5  7/27/2018 13:14:01
# 1  1834490430    False   finalized                   4  7/27/2018 20:04:56
# 2  1834490462    False   finalized                   3  7/27/2018 18:06:19
#
#    choose_a_category:confidence                      created_at  \
# 0                        0.8022  Wed Mar 29 22:45:42 +0000 2017
# 1                        0.4957  Thu Mar 30 11:12:34 +0000 2017
# 2                        1.0000  Fri Mar 31 01:34:08 +0000 2017
#
#                  id_str  rownames  choose_a_category  \
# 0  ,847218235002847232,     38791  direct_eyewitness
# 1  ,847406190225006592,     53402  direct_eyewitness
# 2  ,847623008940204037,     62651  direct_eyewitness
#
#                                                 text  Unnamed: 11
# 0  Ex cyclone Debbie is bringing some bad weather...          NaN
# 1  We r receiving the tail end of cyclone debbie ...          NaN
# 2  Little bit late I know, Cyclone Debbie done me...          NaN

# %%
df7.choose_a_category.value_counts()
# Out:
# choose_a_category
# noneyewitness        1199
# direct_eyewitness     465
# dont_know             336
# Name: count, dtype: int64

# %%
df7 = df7[['choose_a_category','text']]
df7.rename(columns={'choose_a_category': 'label'}, inplace=True)
print(df7.shape)
df7.head(3)
# Out:
# (2000, 2)
#                label                                               text
# 0  direct_eyewitness  Ex cyclone Debbie is bringing some bad weather...
# 1  direct_eyewitness  We r receiving the tail end of cyclone debbie ...
# 2  direct_eyewitness  Little bit late I know, Cyclone Debbie done me...

# %%
disaster_df = pd.concat([df1, df2, df3, df4, df5, df6, df7], axis=0, ignore_index=True)
print(disaster_df.shape)
disaster_df.head(5)
# Out:
# (14000, 2)
#             label                                               text
# 0  non-eyewitness  #earthquake Magnitude 2.1 occurred 159km NE of...
# 1  non-eyewitness  Retweeted Earthquakes Tsunamis (@NewEarthquake...
# 2      don't know  I always know I need to go shopping when I've ...
# 3  non-eyewitness  Update: M2.0 #earthquake (#sismo) strikes 1 km...
# 4  non-eyewitness                                                 ã€

# %%
disaster_df.isnull().sum()
# Out:
# label    0
# text     1
# dtype: int64

# %%
# Drop rows with missing 'text' or 'label'
disaster_df = disaster_df.dropna(subset=['text', 'label'])
print(disaster_df.shape)
disaster_df.head(3)
# Out:
# (13999, 2)
#             label                                               text
# 0  non-eyewitness  #earthquake Magnitude 2.1 occurred 159km NE of...
# 1  non-eyewitness  Retweeted Earthquakes Tsunamis (@NewEarthquake...
# 2      don't know  I always know I need to go shopping when I've ...

# %%
disaster_df.label.value_counts()
# Out:
# label
# don't know                      4652
# noneyewitness                   3329
# direct_eyewitness               2881
# dont_know                       1790
# non-eyewitness                   534
# direct-eyewitness                513
# vulnerable-direct witness        185
# vulnerable direct-eyewitness      84
# indirect-eyewitness               31
# Name: count, dtype: int64

# %%
disaster_df.sample(15)
# Out:
#                    label                                               text
# 5041          don't know  Her heart burns with desire like a volcano, he...
# 1732          don't know  If an earthquake occurred tomorrow &amp; left ...
# 4973          don't know  Happy Earth day to The man, The volcano, The l...
# 2024   direct-eyewitness  Since i'm house arrest today due to the flood ...
# 12800      noneyewitness  Cyclone Debbie in context: how severe was the ...
# 10885      noneyewitness  Canada Wildfire: Convoy Moves Stranded Evacuee...
# 11134      noneyewitness  ABC News  Latest details on path, destruction ...
# 3118          don't know  They flocked to the execution ground like an u...
# 7031   direct_eyewitness                                  YOWZA #earthquake
# 5622          don't know  1c. Also, you can bet the insurance companies ...
# 12893      noneyewitness  Cyclone Debbie dumps bull shark in middle of Q...
# 12746      noneyewitness  It - Hope everyone is keeping safe and warm as...
# 11230      noneyewitness  Omega block behind searing heat inflaming Fort...
# 8887           dont_know  If you want to ask for help from the army at t...
# 9096           dont_know   EveryLibrary Yay! Nothing like annoying publi...

# %%
for i in disaster_df.label.unique():
    print(i)
    print('------------------')
    for j in disaster_df[disaster_df.label == i]['text'].sample(25).to_list():
        print(j)
    print('\n\n')
# Out:
# non-eyewitness
# ------------------
# Kathmandu University flooded, students trying to rescue books.  This and more photo by Sujaan Shrestha on her blogâ€¦ https://t.co/cdukQiRyZ2
# #earthquake (EMSC) https://t.co/ifDmBNb7Vf: mb 3.7 CAUCASUS REGION, RUSSIA https://t.co/jpaHEjD3zM
# One killed as earthquake hits Italian island - Window To News https://t.co/TdyouMnf9o
# #Harvey threatens heavy rainfall/hurricane by Friday. @GovAbbott declared a state of disaster for 30 TX counties: https://t.co/PK7jkbT06S
# 2.2 earthquake close to Erzincan, Turkey at 04:19 UTC! #earthquake #Erzincan https://t.co/raMccETU7a
# 0.6 earthquake occurred 53km ENE of Mammoth Lakes, California at 10:42 UTC! #earthquake #MammothLakes https://t.co/8v1mLtMU93
# The latest Calgary Flood News! https://t.co/wCXLQIpVjk #ableg #abflood
# Magnitude 1.6 earthquake 41km WNW of Goldfield, Nevada https://t.co/9gnS19hFzM
# Prelim M5.7 earthquake Solomon Islands Aug-6 00:15 UTC, updates https://t.co/h6w8vdhWTG, 0 #quake tweets/min
# 2 women save a dog during a flood in India https://t.co/iPxgpshoiU
# 4.16 earthquake hits Mono Lake - At least one person in Gardnerville reported feeling a 4.16 magnitude earthqua... https://t.co/SlHtDg4XdG
# 4.4M earthquake! Thu Aug 24 22:03:33 CDT 2017 near North Atlantic Ocean https://t.co/Nm2ILYz4Hi #earthquake #Sismo
# ...The flood warning extended until Friday morning...The flood warning continues for the Little River Of Louisi #Wx https://t.co/cy0iz3eyQO
# Here the sad news about nepal country that the road of daunne    was destroyed by flood and the passenger are in trâ€¦ https://t.co/VMqIrZgIu3
# Baby rescued from Italian earthquake #RTGWorld
# NewEarthquake: 5.2 earthquake, North Atlantic Ocean. 2017-08-02 00:16:13 UTC at epicenter (21m ago, depth 10km). https://t.co/V0rwZh3dPP
# Assam: Brahmaputra water level recedes, flood toll rises to 150 - The Indian Express https://t.co/fpJvD8HEMN #Assam
# EARTHQUAKES: Shaking near Oklahoma City disrupts calm: A relatively large earthquake shookâ€¦ https://t.co/Ff28c9VMwq
# Magnitude 0.88 earthquake 6km S of Redlands, CA https://t.co/V8OqsDoIZn
# 4.1 earthquake, Portobelo, Panama, 25 Aug., 10:13 am, 27 mi deep, at 9.566Â°,-79.378Â° https://t.co/oyt69xno14
# ML 2.1 WESTERN TURKEY https://t.co/FTwQ4vAAyc #earthquake #Sismo https://t.co/1zF7LZd2Yz
# WARNING: Serious flash flood situation unfolding in KC. Flooding already ongoing, will only get worse overnight w/ storms thru 5 AM
# Franklin becomes the first hurricane of the 2017 Atlantic season. Hurricane Franklin will be a flood threat for parâ€¦ https://t.co/a2FnZhSDVt
# Harvey redevelops into extremely dangerous flood threat for #Tx + #La - Hurricane Watch #hurricanestrong  NOAA: https://t.co/sNFBf3DxgX
# 512 evacuees remain at flood relief centres in Malacca https://t.co/5lW6vc1Y3m https://t.co/ItOSnJPGjU
#
#
#
# don't know
# ------------------
# I wish I'd done before pics of the house. It now looks like a toy shop has exploded in every room, with a mini flood in the bathroom
# Solar Power Mart - Solar Battery, Sealed Lead Acid, Lithium polymer, flood battery, Rechargeable, Trojan, Gel,Â M... https://t.co/7jkyHY1VLX
# "What to do before, during and after an earthquake? #QuakePH #LindolP..."  #LindolPH https://t.co/vuWhW4HUCk
# "Out of the overflow of the heart, the mouth speaks"
# Will become the cause of major transformation not only in India but whole world https://t.co/5h2Ma1EewR #earthquake #TripleTalaq #joincyssrj
# I said I'd love you forever, come hell or highwater... well babe the flood's in
# no flood can cleanse my sinful self
# @realDonaldTrump As someone who has experienced 5 hurricanes, it's a little late to be leaving the scene. They'll gâ€¦ https://t.co/ZNgiP5bCug
# What happens when FEMA gets a request to help out hurricane victims? Do they check to see if they enrolled? Is therâ€¦ https://t.co/5GwZKsrf3r
# Yes earthquakes happen across the region https://t.co/ANEXRgnUrJ
# PSA: thank u hurricane harvey. https://t.co/3qxlvhjLVY
# morons, imbeciles and idiots run hollywood. Can't wait until that big earthquake drops that cess pool in the ocean! https://t.co/HUyQCwWZJp
# If there is an earthquake soon I just hope I'm with my animals so I can protect them
# Everyone acting like hurricanes are the only source of water that can flood a city? In addition to rain I have some bad news about rivers.
# Hey texas, u shouldn't have let gays get married (or is it abortion?). now u got a tsunami on ur hands! #hurricaneharvey
# " I am the calm after a storm,  Yet I am the rain in the middle of a hurricane " https://t.co/yeopmnEIqw
# During earthquake: If you are in a vehicle, pull over to a clear location and stop. Avoid bridgesoverpasses and power lines if possible
# Not another Pouting in a rain storm and having to take a wicked piss.  in the hotel elevator! #babyhorse
# FLOOD  not hurricane  flood = water hurricane = heavy winds https://t.co/3VSHefjXVk
# @realDonaldTrump Is this your hurricane plan - FEMA Director moves to cut support for flood-prone homes - see: https://t.co/qeTyewqANn
# flowers daffodils snout flush drip worn olfactory soak flood fatigue
# @shelbycragg I welcome the flood.
# Be one of the first to join to take advantage of the flood of traffic your ads will receive every day. You Need Leads and You Need Sign-Ups
# @byunsdick this whole earthquake warnings are making me so anxious you have no idea
# @MycaLynn Well, when the next big earthquake hits wonder who'll they get federal aid from?
#
#
#
# direct-eyewitness
# ------------------
# Yes. I am tweeting while an #earthquake  is happening and our building is effing swaying like crazy. #tokyo #ginza #japan
# @CSGORoll My whole load out drowned in a flood because of hurricane Harvey and I didn't have insurance on my skins
# This damn hurricane! We will be closed tonight due to all the heavy rain (I do a lot of workâ€¦ https://t.co/vVlx9Ewjde
# So nice earthquake in the midnight
# Had an earthquake just now! :(
# More HEAVY rain heading towards Harrisburg. Be ready &amp; prepared for more flooding.  Damaging winds too! https://t.co/uNKtZW0W0r
# ooh that earthquake was strong enough I jumped out of bed and grabbed my glasses #åœ°éœ‡
# There was an earthquake in Padang, I was like running down the stairs and out of my house
# Today is by far the most stressful day in all my time in uni. An earthquake hit (not too bad) but we had to evacuate the building and stuff
# This whole hurricane/storm isn't expected to disappear until Wednesday https://t.co/wK4Auxq1xy
# Heavy rains in Baltimore cause sewage overflow. https://t.co/8EHo3W7BpU
# I think we just experienced a small earthquake.   I noticed a tremble in my hotel @HolidayInn on Quail Springs Parkway in @OklahomaCity_OK
# Well that was the largest earthquake I've felt here with the whoooole building moving for like 30 seconds
# OMG that earthquake was so scary our building was actually evacuated.  https://t.co/sqSh7Kizq3
# that was one long earthquake
# First time to experience an earthquake while on a tall building! #fb
# it's been a while since there was a big earthquake.  i was very scary.  well, good night
# oh no !  big earthquake, big earthquake
# Woke up just moments before that earthquake. Wonder if my natural instinct was kicking in
# This earthquake literally woke me from my sleep, woah.
# Yeah. That was a f*ckin earthquake.
# That was the longest earthquake I've ever felt wtf.
# Omg I just felt the earthquake
# There was a slightly big earthquake.
# Oh, #Florida! Heavy rain &amp; flooding prompt #alligator to try to seek refuge inside suburban home https://t.co/f530LFpd9N via @vdeanfla
#
#
#
# indirect-eyewitness
# ------------------
# Incredible! Heartbreaking. Praying for my family and friends in #Houston   #harveyhurricane https://t.co/HM5bE0i6y2
# the hsm school and my uncles house are right behind eachother and they were ruined in the flash flood )):
# Texas has me going for a spin....my hometown was evacuated for the hurricane then an earthquake in Dallas where my entire family is
# just helped a customer who just came to the U.S after he experienced and witnessed the earthquake in mexico... so sad
# My mom messaged my cousins in Oaxaca to make sure they are okay and one of them said she didnt even feel the earthquake
# my dad volunteered to pump out water, for some of the schools that flood. like that's dangerous to be out during the hurricane doing that â˜¹ï¸
# The earthquake videos coming in from Mexico are absolutely terrifying.
# An earthquake here &amp; a Cat 4 hurricane hitting my hometown. What a day! Going to Dollywood tomorrow with the kids!
# Those near the hurricane in TX, please be safe!!! Luckily my family's house won't flood because of how it's built.
# "Heart literally sank the fact that Mexico City was hit by a major earthquake. Currently checking on family."
# "When you call your dad in Mexico and the first thing he says is "We were just in a major earthquake"  #PrayForMexico "
# My friend Bill lives in Houston. Today they're having heavy rainfall, abt 1.6"/hour. Still praying for everyone's safety. #hurricaneharvey
# F*cking hell...my wife and kids are in Tokyo and they're in the middle of an earthquake   Jesus Murphy just how crap can one day get?
# Some days in Thailand has been insane, there has been massive flood on the road to the city (only have image on my dad's phone)
# @_Smoke There was an earthquake in Dallas, my brother evacuated over there w his fam bc of the hurricane :/
# Happy that my friends are safe during Harvey. Prayers going out to everyone in the hurricane's path. Hope everyoneâ€¦ https://t.co/lclYLSJq8q
# There was an earthquake in Sichuan last night. Thankfully Lin Fan &amp; Yuxuan's families are okay. Our thoughts go out to the families affected
# Finally able to hear from my uncle and know that he and his daughters are safe, the earthquake did not affect them to much #bless #mexico
# There was an earthquake this past night, and the epicenter was right in my parents town x)
# my city is getting a rain storm from the hurricane and hella winds but that's nothing compared to what's going on god i'm so worried
# Heard from friends in Houston, Austin and San Antonio. High winds and heavy rain last night. Everyone is safe. #hurricaneharvey
# Just got this from my neice in TX...... We just had an earthquake...earthquake and hurricane in the same weekend! Only in Texas...fuck yea!
# hurricane and all that in my home home and an eARTHQUAKE IN MY SECOND HOME. I CANT GO ANYHERE.
# We have family in the Houston area. Thank you!!  Go #Texans!@HoustonTexans #hurricaneharvey2017 https://t.co/cKGcrSoAJt
# Was Facetiming my brother in Tokyo when an earthquake . It wasn't strong but took a long time. Glad that he's ok. #tokyo #earthquake
#
#
#
# vulnerable direct-eyewitness
# ------------------
# Can't drive to the gym in a flash flood so I might as well eat everything in my house https://t.co/tmfREgiXNW
# this dumbassssss flood warning woke me up!
# My city is under a flash flood warning, sunny thunderstorms, and strong winds, but it's okay guys, it's 85 degrees.
# All of our phones are going off. Flash flood warnings in the area. Avoid water areas.  we're on the river. #Laughlin #ColoradoRiver
# Flash flood alert. Putting fear into my soul it was so loud and terrifying!!!
# It's AUGUST in Southern California and I have gotten nothing short of 15 flash flood warnings in the past 30 minutes.
# Crazy flash flood warning on my phone with the emergency broadcast siren Thunder &amp; hailing like crazy! Oh #newengland â
# s/o to the flash flood warning for scaring the shit outta me
# Flash flood warning in the Burg
# Just got emergency alert re avoiding flood areas. As I'm in @mta in NYC. This is the new normal. Extreme weather. #climatechanged
# These flash flood warnings are really starting to piss me off man
# Damn all these flash flood warnings woke my ass up
# Bueno now we got a flood warning lmao
# Flash flood warnings here now. Outfield looks like a pond. Flights have been cancelled. If it were me, I'd bang it.
# Flash flood warning for eastern Pima county including Tucson until 8:45pm
# I hate getting flood warnings while staying in a house, cause when I was little I saw houses in Florida just be taken by water
# Ima throw my phone if I get another flood warning
# Use care when commuting. Flash flood warning for our area! Be #MITPrepared  https://t.co/Kd55mNQWbH
# Wtf I was watching She's the Man &amp; this "flash flood warning" interruption
# Y'all I did a little rain dance at work.. and 10 min later it started pouring and we got a flash flood warning
# flash flood in my area, it woke me up from my sleep
# i just got a flash flood emergency alert and my phone played a siren and my instant thought was Tornado!
# phone, warning me every 5 minutes won't get me moving, I get there are fucking flash flood warnings.
# yikes i was listening to jjp and relaxing and my phone started beeping bc if a flash flood warning gREAT
# Oh just got a flash flood warning
#
#
#
# vulnerable-direct witness
# ------------------
# Hoping I stay safe during Hurrican Harvey. #texashurricane #TexasStrong #Texasboy
# Staying home for the hurricane,hopefully it doesn't flood.
# We been seeing Houston flood all year from regular rain soooooo wtf they thought a damn hurricane was gone do
# We getting hit by hurricane and Dallas with an earthquake...fair enough lol
# i hope this hurricane doesnt flood my house :)
# There was an earthquake in dallas and a hurricane is on its way
# Can't sleep. Phone keeps going off with hurricane/tornado/flood alerts.  https://t.co/Gn3eYtvLBQ
# So I wake up to a flash flood warning, a hurricane about to hit corpus, &amp; an earthquake in Irving. Idk about y'all but I'm praying hard
# I hope this hurricane done flood and blow my crib away
# And so it begins. Hoping we don't flood. #hurricaneharvey #harvey #hurricane #storms #beginningâ€¦ https://t.co/gjH2hSImpi
# And so there was a typhoon in Hong Kong, a earthquake in California and now there's a hurricane headed right towards us
# This hurricane about to flood us
# It was a nice day up until 5 mins ago now it looks like there's going to be a hurricane, tornado and tsunami at the same time
# Just hoping the basement of the Alamo doesn't flood in the hurricane.
# Out here in Houston/Katy we got a tornado warning flash flood warning tropical storm warning and last but not least a hurricane warning
# No more rain! It will overflow! #houstonstrong #wewillovercome #hurricaneharvey
# my mom doesn't think the hurricane is actually gonna hit sugar land so she's acting like it's just a little rain storm.......rip
# I really hope that hurricane Harvey does not flood my house please pray for me guys thanks.
# it's just going to flood badly. the news really hyped up the potential hurricane damages
# they're really sending flash flood warnings like there isn't a whole ass hurricane https://t.co/KT4ojf7mW4
# I'm so scared I hope this hurricane don't flood my apartment or my car
# Woke up to an earth quake and now I can see the edges of the hurricane are gonna give use rain all weekend. Lol
# So far I've been in Texas 1week and I've seen a solar eclipse, felt an earthquake, and now there's a hurricane. What else can Texas give me?
# hurricane winds, some heavy rain coming ...eh we got this, we're Paulsens. #4cars #2bikesâ€¦ https://t.co/DfeB7vIIBq
# Don't worry folks I'm gonna be ok during the hurricane! My apartment might flood but me n my stuff are at my parents house w/a generator
#
#
#
# direct_eyewitness
# ------------------
# That earthquake got me fucked up
# That was a big earthquake
# During our work after the earthquake in #Mexico. DANCING IS HEALING! These children, just moments before were downc  https://t.co/mThKm0PCQI
# Am i tweakin or was there just an earthquake
# ah there was definitely an earthquake just now
# Feel that earthquake?
# I thought there was an earthquake going on right now but it  s just this damn train.
# Ok earthquake Twitter: GO!
# Wot ? Ј3 is my Wet Weather Plan today? ѕ‘4 #TCDebbie https://t.co/5RYFFZk6AN
# the other day I was with my bf. We hit high water, his car started to flood, and the very first thing he grabbed wi  https://t.co/MPy1x5YLwt
# was that an earthquake ? #Bayarea #earthquake
# Bruh that earthquake...
# cyclone debbie got a big wet
# Yep that was an earthquake  at least it was short
# Ughhhh earthquake
# My home town getting ready for the deluge of ex tropical cyclone Debbie https://t.co/lWBcqyt0jd
# It is 106 degrees and we just got a flash flood warning and I m not sure if this is real or if that drink had more alcohol than I thought.
#  mulala_evalisto feeling great because as Cyclone Debbie is happening around my state school is cancelled and I can sleep
# Omg this earthquake just scared tf outta me
# My class is cancelled today as a result of Cyclone Debbie. I'll take this as an opportunity to relax and try to get ahead of my classes! іF ЌA
# Just felt an earthquake and first reaction was this better not be a big one because I gotta watch this 2nd half.
# That earthquake woke me outta my nap quickkkk lol
# It is so crazy to see and the smell is quite strong! #wildfire  https://t.co/raVqKWggFF
# We r receiving the tail end of cyclone debbie theres lots of flooding and all schools in queensland Aust have been closed the wind is wild
# Nice little #earthquake, that one #SanFrancisco
#
#
#
# dont_know
# ------------------
# Maria's Donkey in very bad shape as Pioneer River climbs  daily_mercury #Mackay #CycloneDebbie #TCDebbie https://t.co/ddrpx1rRxv
# I love this :')  https://t.co/hkc25MeJxh
# Plainfield students create earthquake-proof buildings https://t.co/yde000jC1d https://t.co/gmuwwt446H
# WHY? Would Hillary Clinton want to flood America with Islamic Muslims that want to kill Christians and Jews https://t.co/6l3nG6KPKX
# Is it wrong I look at this loop and think of brisket? #sorrycali #doyouseeit https://t.co/rdpp4BkKqa
# I didn't know I had this flood of emotions before cause I was too busy
# Can we just ONE day without having a scare mongering story. #extinction #floods #drought #hurricanes ##tsunamis  https://t.co/Q9w0FpPPzd
# Should have got  RichardHammond. To talk about animals! https://t.co/Mjzy63FGEA
#  TheKateWall Haha she's outstayed her welcome #TCDebbie
# No fireworks for us tonight. Ena and Jamelah seem to be interested in watching the flood world show on KPRC.
# guac I feel will come a big earthquake here in stgo
# I was just thinking about him yesterday. That's fantastic news! https://t.co/Yn5gpJQWxm
# Icing on the poop cake. Or the earth climaxing after taking a psychic dump. #earthquake
#  FefylovesYou Make sure you flood the TL
# baby earthquake?
# Looks great until the river floods, but put this whole thing on stilts (and maybe pontoons, if you really want it t  https://t.co/hErKLTrSqa
#  DavidWright_CNN  MalcolmNance  JennaMC_Laugh We need to flood the streets with protests for Putin s visit. For days.
# Distal accessing for anywhere everywhither the superfluity-carry over files, guide programs, flood wicker reso...
# abcbrisbane  AnnastaciaMP price hiking to profit in these times is not permitted who will act on this? https://t.co/A4ERtX84my
# Just awoke from a dream... I was on a bus traveling in the rain and it was flooding.  #Overflow #Change #Growth
# oh shit https://t.co/Gd6fUu1MYB
# #PeakMediaDebbie has been reached https://t.co/sNkIfEBA7p
# You know all those people who flood Twitter when a Marvel movie comes out and say "If you don't like it, be quiet a  https://t.co/Vn9GIaCZUi
# A model for every nation that has been foolish enough to permit these muslim immigrants to flood their countries an  https://t.co/NNmhAIGq08
# Sandman_HQ Same here, and with only 5 days left, its time to flood this petition. Needs to be completed and kicked  https://t.co/8Qj3wO8I9f
#
#
#
# noneyewitness
# ------------------
# well atleast that solved the drought problem?? maybe debbie was like qld is in drought! no water?? NEVER FEAR CYCLONE DEBBIE IS HERE
# в›€ We hope everyone in Queensland is safe and dry! ›€ Coincidentally, ex-tropical cyclone Debbie has  struck UQ... https://t.co/etv9ST420K
# Please pray for all the people in California effected by the wildfires. Currently, 15 have died  https://t.co/wWwnyNe4Mh
# I liked a  YouTube video from  andysfishing https://t.co/9tdD41677W Cyclone Debbie Natural Disaster How I Survived EP.355
# Fort McMurray wildfire resident in convoy through community calls scene  very Apocalyptic  #TODAY https://t.co/MtMmPGXtxE
# Another earthquake, brought to you by  HannahTienken cc:  sarahburchfield
# It is NEVER safe to drive or walk into flood waters. Check out this video from the National Weather Service.  https://t.co/JNaTHOBgQP
# Debbie the cockatoo dies after cyclone https://t.co/7NfVlIDsn6
# All guests have been evacuated from #daydreamisland today thankfully  #TCDebbie
# Wildfires Threaten California s First Legal Cannabis Harvest https://t.co/BSuAdfwN62 https://t.co/wNqfLrNmTp
# Morrison: Still extreme wildfire behaviour. #ymmfire
# Cyclone Debbie is rolling into NSW. With expected damaging winds and https://t.co/8JgyG03h0o
# At least 17 dead as California wildfires rage: At least 17 people have died in California  https://t.co/pEa1E8bw6S
# Extremely dangerous behaviour captured at Murwillumbah Weir. TCDebbie qldweather 7News https://t.co/qXbzp8EonS
# Family safe, floodwaters, 1/2 day fresh water reserves in Mackay, huge cleanup in Far North Queensland as Cyclone D https://t.co/z3ntHLRgqb
# Grocery prices will rise across Australia because of Cyclone Debbie. Here s what isВ affected https://t.co/UNzV9aKesi https://t.co/ortzhpEuYO
# LITTLE AUSSIE BATTLER: Good news amid the heartache caused by Cyclone Debbie. Townsville Bulletin's rescue... https://t.co/iRYoJFb5LW
# Severe flood situation alert for public issued by Central Water Commission.  #weatheralert #floodalert #NewDelhi https://t.co/7yy65JwpVX
# Schools closed as Brisbane braces for 'nightmare' in Cyclone Debbie's wake https://t.co/qVJhTJQhR3
# A #Graceville underground car park is flooding rapidly as ex-cyclone Debbie dumps large rainfall in SE #Queensland. https://t.co/3UjU1N7nS1
# Our journos are covering flood events from Mackay to the NSW boarder. Stay up-to-date with QCL weather #TCDebbie https://t.co/AQmNq3gpFU
# Big news for Cedar Rapids: 10 years after it was hit by a devastating flood, federal flood protection money is fina  https://t.co/KtuRXAdBs7
# After jokey start, Canadian PM Trudeau promises wildfire help https://t.co/Q6NoHedPZQ via *Reuters
# Tropical Cyclone Debbie, 2017-03-30 05:11:31 UTC https://t.co/LGMG2YIZc6 #disaster #typhoon #video
# Oakland #earthquake 7:18pm 4 seconds Long

# %%
non_real_time_crisis = ["non-eyewitness", "don't know", "dont_know","noneyewitness"]
real_time_crisis = ["direct-eyewitness","vulnerable direct-eyewitness", "vulnerable-direct witness", "indirect-eyewitness", "direct_eyewitness"]

for i in non_real_time_crisis:
    disaster_df['label'] = disaster_df['label'].replace(i, 'non_real_time_crisis')
for i in real_time_crisis:
    disaster_df['label'] = disaster_df['label'].replace(i, 'real_time_crisis')
disaster_df.label.value_counts()
# Out:
# label
# non_real_time_crisis    10305
# real_time_crisis         3694
# Name: count, dtype: int64

# %%
for i in disaster_df.label.unique():
    print(i)
    print('------------------')
    for j in disaster_df[disaster_df.label == i]['text'].sample(5).to_list():
        print(j)
    print('\n\n')
# Out:
# non_real_time_crisis
# ------------------
# All of my Boston friends, flood city hall with emails and phone calls next week https://t.co/2vZoBXIvX1
# hoseok : can you feel my heart beat ?   * causes earthquake *
# Why does it decide to flood in 29 when I'm gone, I'm not ok with that
# Can you answer this? The major earthquake that struck Japan was not far offshore https://t.co/sfA9VQhE02
# Los Angeles News Search LA (Health risks of flood waters after hurricanes: What to expect after Harvey) 1 Los ... - https://t.co/wfWhMGSkXw
#
#
#
# real_time_crisis
# ------------------
# Dead bull shark washes up in severe floods https://t.co/FturCOwjIW
# earthquake twitter: ACTIVATE!
# Such a horrible little earthquake at 2:00am. I forget how scary they are
# no uni today thanks cyclone debbie
# I knew those little earthshakes an hour ago would turn into an earthquake. #Oakland

# %%
disaster_df.label.value_counts()
# Out:
# label
# non_real_time_crisis    10305
# real_time_crisis         3694
# Name: count, dtype: int64

# %%
disaster_df.text.iloc[4]
disaster_df[disaster_df.text == disaster_df.text.iloc[3128]]
# Out:
#                      label   text
# 3128  non_real_time_crisis  âš ï¸

# %%
disaster_df.head(5)
# Out:
#                   label                                               text
# 0  non_real_time_crisis  #earthquake Magnitude 2.1 occurred 159km NE of...
# 1  non_real_time_crisis  Retweeted Earthquakes Tsunamis (@NewEarthquake...
# 2  non_real_time_crisis  I always know I need to go shopping when I've ...
# 3  non_real_time_crisis  Update: M2.0 #earthquake (#sismo) strikes 1 km...
# 4  non_real_time_crisis                                                 ã€

# %%
disaster_df.label.value_counts()
# Out:
# label
# non_real_time_crisis    10305
# real_time_crisis         3694
# Name: count, dtype: int64

# %%
disaster_df
# Out:
#                      label                                               text
# 0         real_time_crisis  I was wondering why the room was shaking when ...
# 1         real_time_crisis  Another earthquake woke me up at the night. No...
# 2         real_time_crisis  F*cking hell...my wife and kids are in Tokyo a...
# 3         real_time_crisis  Was Facetiming my brother in Tokyo when an ear...
# 4         real_time_crisis  I just called my grandma asking if she was ok ...
# ...                    ...                                                ...
# 7383  non_real_time_crisis  Another strong bid to change the spelling of "...
# 7384  non_real_time_crisis  man I m so lucky there s no flood here in my n...
# 7385  non_real_time_crisis  Very powerful #CycloneDebbie has made landfall...
# 7386  non_real_time_crisis  Also, California should expect an calamitous e...
# 7387  non_real_time_crisis  Giant wildfire turns Canadian oil country into...
#
# [7388 rows x 2 columns]

# %%
disaster_df.to_csv('../data/processed/disaster_df.csv', index=False)

# %% [markdown]
# ## Balance the data

# %%
disaster_df_non_real_time_crisis = disaster_df[disaster_df.label == 'non_real_time_crisis']
disaster_df_real_time_crisis = disaster_df[disaster_df.label == 'real_time_crisis']
print(disaster_df_non_real_time_crisis.shape)
print(disaster_df_real_time_crisis.shape)
disaster_df_non_real_time_crisis = disaster_df_non_real_time_crisis.sample(n=disaster_df_real_time_crisis.shape[0])
disaster_df = pd.concat([disaster_df_real_time_crisis, disaster_df_non_real_time_crisis], axis=0, ignore_index=True)
print(disaster_df.shape)
disaster_df.label.value_counts()
# Out:
# (10305, 2)
# (3694, 2)
# (7388, 2)
# label
# real_time_crisis        3694
# non_real_time_crisis    3694
# Name: count, dtype: int64

# %% [markdown]
# ## Split the data

# %%
train, test = train_test_split(disaster_df, test_size=0.1, random_state=42, stratify=disaster_df['label'])
train.shape, test.shape
# Out:
# ((6649, 2), (739, 2))

# %%
train.head(5)
# Out:
#                      label                                               text
# 2675      real_time_crisis  RodyDu30: RT teddyboylocsin: For two days now,...
# 834       real_time_crisis   PolhomeEditor  duncanm Buildings first earthq...
# 2023      real_time_crisis                           The rare May earthquake.
# 4433  non_real_time_crisis  @CMYogiAditya It's humble request, building ma...
# 3897  non_real_time_crisis  And you probably thought Sharknado was a stupi...

# %%
test.head(5)
# Out:
#                      label                                               text
# 4334  non_real_time_crisis                        can my house not flood? :^)
# 5342  non_real_time_crisis  Dan your "quick break" didn't come quick enoug...
# 3336      real_time_crisis            Am I gonna die? https://t.co/isr23xgeqP
# 4302  non_real_time_crisis                                     earthquake rip
# 4392  non_real_time_crisis  Tasmanian emergency services assist in recover...

# %% [markdown]
# ## Preprocess text

# %%
## Preprocess the text
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    
    # text = re.sub(r'@\w+', '', text)  # Remove mentions
    # text = re.sub(r'#\w+', '', text)  # Remove hashtags
    # text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # Remove URLs
    text = re.sub(r'\d+', '', text)  # Remove numbers
    # text = re.sub(r'\s+', ' ', text)  # Remove extra whitespace
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters
    text = re.sub(r'\s+', ' ', text)  # Remove extra whitespace
    text = text.strip()  # Remove leading/trailing whitespace


    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop]  # Lemmatization and remove stop words
    return ' '.join(tokens)

# %%
train['text'] = train.text.apply(preprocess_text)
test['text'] = test.text.apply(preprocess_text)

# %%
train.head(5)
# Out:
#                      label                                               text
# 2675      real_time_crisis  rodydu rt teddyboylocsin day traffic sure mass...
# 834       real_time_crisis          polhomeeditor duncanm building earthquake
# 2023      real_time_crisis                                    rare earthquake
# 4433  non_real_time_crisis  cmyogiaditya humble request building collapse ...
# 3897  non_real_time_crisis  probably think sharknado stupid unrealistic mo...

# %%
test.head(5)
# Out:
#                      label                                               text
# 4334  non_real_time_crisis                                        house flood
# 5342  non_real_time_crisis  dan quick break not come quick not unsee butt ...
# 3336      real_time_crisis                         go to die httpstcoisrxgeqp
# 4302  non_real_time_crisis                                     earthquake rip
# 4392  non_real_time_crisis  tasmanian emergency service assist recovery ef...

# %%
train_cleaned = train[train.text != ''].copy()
test_cleaned = test[test.text != ''].copy()

# %%
train_cleaned.head(5)
# Out:
#                      label                                               text
# 2675      real_time_crisis  rodydu rt teddyboylocsin day traffic sure mass...
# 834       real_time_crisis          polhomeeditor duncanm building earthquake
# 2023      real_time_crisis                                    rare earthquake
# 4433  non_real_time_crisis  cmyogiaditya humble request building collapse ...
# 3897  non_real_time_crisis  probably think sharknado stupid unrealistic mo...

# %%
test.head(5)
# Out:
#                      label                                               text
# 4334  non_real_time_crisis                                        house flood
# 5342  non_real_time_crisis  dan quick break not come quick not unsee butt ...
# 3336      real_time_crisis                         go to die httpstcoisrxgeqp
# 4302  non_real_time_crisis                                     earthquake rip
# 4392  non_real_time_crisis  tasmanian emergency service assist recovery ef...

# %%
def format_for_fasttext(df, text_col, label_col, output_path):
    with open(output_path, 'w', encoding='utf-8') as f:
        for text, label in zip(df[text_col], df[label_col]):
            f.write(f"__label__{label} {text.strip()}\n")

format_for_fasttext(train_cleaned, 'text', 'label', '../data/processed/train.txt')
format_for_fasttext(test_cleaned, 'text', 'label', '../data/processed/test.txt')

# %%
# with open('../data/processed/train.txt', 'r', encoding='utf-8') as f:
#     for i, line in enumerate(f):
#         if not line.strip():
#             print(f"Empty line at {i}")
#         if '__label__' not in line:
#             print(f"Missing label at line {i}")

# %% [markdown]
# ## Train Fasttext

# %%
model = fasttext.train_supervised(input='../data/processed/train.txt', loss='hs')
# model = fasttext.train_supervised(input='../data/processed/debug_train.txt', loss='hs')
# Out:
# Read 0M words
# Number of words:  11872
# Number of labels: 2
# Progress: 100.0% words/sec/thread:  454569 lr:  0.000000 avg.loss:  0.481863 ETA:   0h 0m 0s

# %%
model.test('../data/processed/test.txt')
# Out:
# (739, 0.803788903924222, 0.803788903924222)

# %%
text = "just felt an hurricane"
labels, probabilities = model.predict(text, k=1)
print(labels[0], probabilities[0])
# Out:
# __label__non_real_time_crisis 0.9838029146194458
